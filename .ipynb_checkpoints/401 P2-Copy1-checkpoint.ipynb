# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
import scipy.stats as st
from scipy.optimize import curve_fit

# %%
df = pd.read_csv('term_project_overlay_data.csv').drop('overlay_error_x', axis = 1, inplace = False)
OyOriginal = df[' overlay_error_y']
df.drop(' overlay_error_y', axis = 1, inplace = True)
dataOriginal = df.values

df.rename(columns={' x': 'x'}, inplace = True)

# %%
dfOx = pd.read_csv('term_project_overlay_data.csv')
OxOriginal = dfOx['overlay_error_x']

# %%
len(OyOriginal)
# Out:
# 250

# %%
dfout = df
dfout['x2'] = df['x']*df['x']
dfout['y2'] = df['y'] * df['y']
dfout['xy'] = df['x'] * df['y']
dfout['X2'] = df['X'] * df['X']
dfout['Y2'] = df['Y'] * df['Y']
dfout['XY'] = df['X'] * df['Y']
dfout['0'] = 1
dfout = dfout[['0', 'X', 'Y', 'XY', 'X2', 'Y2', 'x', 'y', 'xy', 'x2', 'y2']]
dfout.to_csv("dataProcessed.csv", index = None)

# %%
len(dfout)
# Out:
# 250

# %%
OyOriginal.to_csv("overlay_y.csv", index = None)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
def funcOy (data, b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10):
    x, X, y, Y = data
    return b0 + b1*X + b2*Y + b3*X*Y + b4*X*X + b5*Y*Y + b6*x + b7*y + b8*x*y + b9*x*x + b10*y*y;

# %%
def funCal (popt, datai, yi):
    x, X, y, Y = datai
    ycal = popt[0] + popt[1]*X + popt[2]*Y + popt[3]*X*Y + popt[4]*X*X + popt[5]*Y*Y + popt[6]*x + popt[7]*y + popt[8]*x*y + popt[9]*x*x + popt[10]*y*y
    return (yi - ycal)**2

# %%
def calPress (dataOriginal):
    PRESS = 0;
    for i in range(0, len(dataOriginal)):
        data = np.delete(dataOriginal, i, 0)
        data = data.T
        Oy = np.delete(OyOriginal, i)
        popt, pcov = curve_fit(funcOy, data, Oy)
        PRESS = PRESS + funCal (popt, dataOriginal[i], OyOriginal[i])
    
    print(PRESS)

# %%
calPress(dataOriginal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d22909a59085> in <module>
# ----> 1 calPress(dataOriginal)
#
# <ipython-input-9-69ddf857bf46> in calPress(dataOriginal)
#       4         data = np.delete(dataOriginal, i, 0)
#       5         data = data.T
# ----> 6         Oy = np.delete(OyOriginal, i)
#       7         popt, pcov = curve_fit(funcOy, data, Oy)
#       8         PRESS = PRESS + funCal (popt, dataOriginal[i], OyOriginal[i])
#
# <__array_function__ internals> in delete(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in delete(arr, obj, axis)
#    4425
#    4426     if wrap:
# -> 4427         return wrap(new)
#    4428     else:
#    4429         return new
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __array_wrap__(self, result, context)
#    1997     def __array_wrap__(self, result, context=None):
#    1998         d = self._construct_axes_dict(self._AXIS_ORDERS, copy=False)
# -> 1999         return self._constructor(result, **d).__finalize__(self)
#    2000
#    2001     # ideally we would define this to avoid the getattr checks, but
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     297                         raise ValueError(
#     298                             "Length of passed values is {val}, "
# --> 299                             "index implies {ind}".format(val=len(data), ind=len(index))
#     300                         )
#     301                 except TypeError:
#
# ValueError: Length of passed values is 249, index implies 250

# %%
def funcOx (data, b0, b2, b3, b4, b6, b7, b9, b10):
    x, X, y, Y = data
    return b0+ b2*Y + b3*X*Y + b4*X*X + b6*x + b7*y+ b9*x*x + b10*y*y;

# %%
def calOyPredicted(popt, data):
    x, X, y, Y = data
    return  popt[0] + popt[1]*X + popt[2]*Y + popt[3]*X*Y + popt[4]*X*X + popt[5]*Y*Y + popt[6]*x + popt[7]*y + popt[8]*x*y + popt[9]*x*x + popt[10]*y*y

# %%
def calOxPredicted(popt,data):
    x, X, y, Y = data
    return  popt[0] + popt[1]*Y + popt[2]*X*Y + popt[3]*X*X  + popt[4]*x + popt[5]*y +  popt[6]*x*x + popt[7]*y*y

# %%
def funcOxFull (data, b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10):
    x, X, y, Y = data
    return b0 + b1*X + b2*Y + b3*X*Y + b4*X*X + b5*Y*Y + b6*x + b7*y + b8*x*y + b9*x*x + b10*y*y;

# %%
def calOxPredictedFull(popt,data):
    x, X, y, Y = data
    return  popt[0] + popt[1]*X + popt[2]*Y + popt[3]*X*Y + popt[4]*X*X + popt[5]*Y*Y + popt[6]*x + popt[7]*y + popt[8]*x*y + popt[9]*x*x + popt[10]*y*y

# %%
    poptxfull,pcovx = curve_fit(funcOxFull, data, OxOriginal)
    Ox_fittedFull = calOxPredictedFull(poptxfull,data)

# %%
    data = dataOriginal.T
    poptx,pcovx = curve_fit(funcOx, data, OxOriginal)
    Ox_fitted = calOxPredicted(poptx,data)
    popt, pcov = curve_fit(funcOy, data, OyOriginal)
    Oy_fitted = calOyPredicted(popt, data)

# %%
    fig1 = plt.figure()
    Ox_scatter = fig1.add_subplot(111)
    Ox_scatter.scatter(OxOriginal, OyOriginal, label='Actual $(o_x, o_y)$', marker='.', linewidth=1)
    Ox_scatter.scatter(Ox_fittedFull, Oy_fitted, label='Estimated $(\hat{o_x}, \hat{o_y})$', marker='.', linewidth=1)
    Ox_scatter.set_xlabel('$o_x$')
    Ox_scatter.set_ylabel('$o_y$')
    Ox_scatter.legend()
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
    fig1 = plt.figure()
    Ox_scatter = fig1.add_subplot(111)
    Ox_scatter.scatter(OxOriginal, OyOriginal, label='Actual $(o_x, o_y)$', marker='.', linewidth=1,alpha=0.6)
    Ox_scatter.scatter(Ox_fitted, Oy_fitted, label='Estimated $(\hat{o_x}, \hat{o_y})$', marker='.', linewidth=1, alpha=0.6)
    Ox_scatter.set_xlabel('$o_x$')
    Ox_scatter.set_ylabel('$o_y$')
    Ox_scatter.legend()
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
